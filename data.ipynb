# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset

# train data
data1 = np.load("CNN/data1.npy")
data2 = np.load("CNN/data2.npy")
data3 = np.load("CNN/data3.npy")
data4 = np.load("CNN/data4.npy")

# 합치기
train_data = np.concatenate([data1, data2, data3, data4], axis=0)

# test data
test_data = np.load("CNN/test_data.npy")
test_label = np.load("CNN/test_label.npy")

print(train_data.shape)
print(test_data.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import torch
#       3 from torch.utils.data import DataLoader, TensorDataset
#
# ModuleNotFoundError: No module named 'numpy'
